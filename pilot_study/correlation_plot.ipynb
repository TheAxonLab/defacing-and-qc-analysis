# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from mriqc_learn.datasets import load_dataset
from mriqc_learn.models.preprocess import SiteRobustScaler

(train_x, train_y), _ = load_dataset(split_strategy="none")
train_x = train_x.drop(columns=[
    "size_x",
    "size_y",
    "size_z",
    "spacing_x",
    "spacing_y",
    "spacing_z",
])
numeric_columns = train_x.columns.tolist()
train_x["site"] = train_y.site

# Harmonize between sites
scaled_x = SiteRobustScaler(unit_variance=True).fit_transform(train_x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_76230/1711422800.py in <module>
# ----> 1 from mriqc_learn.datasets import load_dataset
#       2 from mriqc_learn.models.preprocess import SiteRobustScaler
#       3
#       4 (train_x, train_y), _ = load_dataset(split_strategy="none")
#       5 train_x = train_x.drop(columns=[
#
# ModuleNotFoundError: No module named 'mriqc_learn'

# %%
from mriqc_learn.viz import metrics

metrics.plot_corrmat(scaled_x[numeric_columns].corr(), figsize=(14,14), sorted=True)
