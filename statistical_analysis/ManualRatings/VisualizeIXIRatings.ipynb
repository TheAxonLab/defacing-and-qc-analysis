# %% [markdown]
# # Visualize manual ratings

# %% [markdown]
# ## Load simulated or collected manual ratings

# %%
df <- read.csv(file = '../../data/IXI_ratings_df.csv')
# Drop columns we will not use in the analysis
df <- df[, !names(df) %in% c("dataset", "artifacts", "time_sec", "confidence", "comments")]

df
# Out:
#      X    rater_id subject      rating
# 1     0   emeline  sub-0152_T1w 2.45
# 2     1   emeline  sub-0152_T1w 2.55
# 3     2   emeline  sub-1051_T1w 2.85
# 4     3   emeline  sub-1186_T1w 2.55
# 5     4   emeline  sub-0951_T1w 3.45
# 6     5   emeline  sub-0902_T1w 2.95
# 7     6   emeline  sub-0250_T1w 2.55
# 8     7   emeline  sub-0394_T1w 2.95
# 9     8   emeline  sub-0924_T1w 2.60
# 10    9   emeline  sub-0472_T1w 2.65
# 11   10   emeline  sub-0328_T1w 3.00
# 12   11   emeline  sub-0661_T1w 3.55
# 13   12   emeline  sub-0050_T1w 2.60
# 14   13   emeline  sub-1221_T1w 2.85
# 15   14   emeline  sub-0752_T1w 3.15
# 16   15   emeline  sub-0336_T1w 3.55
# 17   16   emeline  sub-0459_T1w 2.95
# 18   17   emeline  sub-0775_T1w 3.40
# 19   18   emeline  sub-1130_T1w 2.70
# 20   19   emeline  sub-0656_T1w 3.25
# 21   20   emeline  sub-0270_T1w 2.80
# 22   21   thomas   sub-0152_T1w 3.55
# 23   22   thomas   sub-1051_T1w 3.70
# 24   23   thomas   sub-1186_T1w 3.30
# 25   24   thomas   sub-0951_T1w 3.35
# 26   25   thomas   sub-0902_T1w 3.30
# 27   26   thomas   sub-0250_T1w 3.45
# 28   27   thomas   sub-0394_T1w 3.45
# 29   28   thomas   sub-0924_T1w 3.00
# 30   29   thomas   sub-0472_T1w 3.40
# ⋮    ⋮    ⋮        ⋮            ⋮
# 1781 1780 elda     sub-1116_T1w 3.15
# 1782 1781 elda     sub-1223_T1w 2.95
# 1783 1782 elda     sub-0161_T1w 3.30
# 1784 1783 elda     sub-1190_T1w 2.95
# 1785 1784 elda     sub-1179_T1w 3.65
# 1786 1785 elda     sub-1168_T1w 3.30
# 1787 1786 elda     sub-0466_T1w 2.95
# 1788 1787 elda     sub-0558_T1w 3.05
# 1789 1788 elda     sub-0947_T1w 3.55
# 1790 1789 elda     sub-1091_T1w 3.45
# 1791 1790 elda     sub-0937_T1w 2.90
# 1792 1791 elda     sub-0957_T1w 2.45
# 1793 1792 elda     sub-0331_T1w 4.00
# 1794 1793 elda     sub-0457_T1w 3.45
# 1795 1794 elda     sub-0880_T1w 3.10
# 1796 1795 elda     sub-1189_T1w 3.50
# 1797 1796 elda     sub-0544_T1w 3.25
# 1798 1797 elda     sub-1097_T1w 3.25
# 1799 1798 elda     sub-0722_T1w 3.40
# 1800 1799 elda     sub-0792_T1w 2.95
# 1801 1800 elda     sub-1230_T1w 3.20
# 1802 1801 elda     sub-0550_T1w 2.75
# 1803 1802 elda     sub-0036_T1w 3.25
# 1804 1803 elda     sub-0386_T1w 3.40
# 1805 1804 elda     sub-0879_T1w 2.95
# 1806 1805 elda     sub-0640_T1w 3.55
# 1807 1806 elda     sub-1231_T1w 4.00
# 1808 1807 elda     sub-1048_T1w 3.45
# 1809 1808 elda     sub-0468_T1w 2.85
# 1810 1809 elda     sub-0203_T1w 3.45

# %% [markdown]
# First, let us verify that the 4 raters rated all the 450 images.

# %%
raters <- list('elda', 'emeline', 'jaime', 'thomas')
for (rater in raters) {
  df_rater <- subset(df, rater_id == rater)
  # If an image was assigned several ratings by the same rater, we keep only the last one
  df_unique <- df_rater[!duplicated(df_rater[c("rater_id", "subject")], fromLast = TRUE), ]
  print(paste(rater, ":", nrow(df_unique), "images rated"))
}
# Out:
# [1] "elda : 450 images rated"
# [1] "emeline : 450 images rated"
# [1] "jaime : 450 images rated"
# [1] "thomas : 450 images rated"

# %% [markdown]
# ### Plot ratings distribution

# %% [markdown]
# To verify that a bias is visible in the data, we plot for each rater the ratings distribution differentially for the defaced vs original conditions.

# %%
## Create dataframe with frequency counts
df_small <- data.frame(rater = df$rater, ratings = df$ratings, defaced =df$defaced)
conTable <- table(df_small)
df_freq <- as.data.frame(conTable)
df_freq
# Out:
#     rater   ratings defaced  Freq
# 1   rater01 1       original 0
# 2   rater02 1       original 0
# 3   rater03 1       original 1
# 4   rater04 1       original 0
# 5   rater01 2       original 0
# 6   rater02 2       original 1
# 7   rater03 2       original 0
# 8   rater04 2       original 0
# 9   rater01 3       original 0
# 10  rater02 3       original 1
# 11  rater03 3       original 0
# 12  rater04 3       original 1
# 13  rater01 4       original 1
# 14  rater02 4       original 0
# 15  rater03 4       original 2
# 16  rater04 4       original 0
# 17  rater01 5       original 0
# 18  rater02 5       original 0
# 19  rater03 5       original 1
# 20  rater04 5       original 1
# 21  rater01 6       original 1
# 22  rater02 6       original 2
# 23  rater03 6       original 0
# 24  rater04 6       original 0
# 25  rater01 7       original 1
# 26  rater02 7       original 0
# 27  rater03 7       original 1
# 28  rater04 7       original 2
# 29  rater01 8       original 1
# 30  rater02 8       original 1
# ⋮   ⋮       ⋮       ⋮        ⋮
# 443 rater03 52      defaced  2
# 444 rater04 52      defaced  0
# 445 rater01 53      defaced  0
# 446 rater02 53      defaced  1
# 447 rater03 53      defaced  0
# 448 rater04 53      defaced  0
# 449 rater01 54      defaced  0
# 450 rater02 54      defaced  2
# 451 rater03 54      defaced  3
# 452 rater04 54      defaced  0
# 453 rater01 55      defaced  1
# 454 rater02 55      defaced  0
# 455 rater03 55      defaced  2
# 456 rater04 55      defaced  0
# 457 rater01 56      defaced  0
# 458 rater02 56      defaced  4
# 459 rater03 56      defaced  0
# 460 rater04 56      defaced  0
# 461 rater01 57      defaced  0
# 462 rater02 57      defaced  1
# 463 rater03 57      defaced  0
# 464 rater04 57      defaced  0
# 465 rater01 58      defaced  3
# 466 rater02 58      defaced  0
# 467 rater03 58      defaced  1
# 468 rater04 58      defaced  0
# 469 rater01 59      defaced  0
# 470 rater02 59      defaced  0
# 471 rater03 59      defaced  1
# 472 rater04 59      defaced  0

# %%
options(repr.plot.width = 30, repr.plot.height = 20)
library(ggplot2)
## Bar plot
ggplot(df_freq, aes(x = rater, y = Freq))+
  geom_bar(
    aes(fill = ratings), stat = "identity", color = "white",
    position = position_dodge(0.9) 
    )+
  facet_wrap(~defaced)+
  theme(text = element_text(size = 25))+
  theme(axis.text.x = element_text(size = 15))
# Out:
# plot without title

# %% [markdown]
# ## Continous ratings

# %% [markdown]
# Simulate human ratings of image quality. The ratings are randomly sampled from [0,1] at 0.1 increment and randomly distributed across subjects. To introduce a bias in the ratings of defaced images, we add +0.2 to a predefined precentage of the ratings on original images. The percentage of scan affected varies between raters.

# %%
## Simulate continuous data with bias
n_rated <- 185
n_sub <- 185 #nbr of subjects available in the dataset
n_rater <- 4 #nbr of raters
perc_biased <- c(2,10,60,90) #4 raters + bias
ratings_range <- seq(0,1,length.out=11)
labels <- c('excluded','0.1','poor','0.3','acceptable','0.5','good','0.7','very good','0.9','excellent')
bias <- 0.2
file_name <- 'SimulatedData/SimulatedDefacedRatings_continuous.Rda'

source("simulate_data.R")

df_cont <- simulate_data(n_rated, n_sub, n_rater, perc_biased, ratings_range=ratings_range, labels=labels, bias=bias, file=file_name)

# %%
## Create dataframe with frequency counts
df_cont_small <- data.frame(rater = df_cont$rater, ratings = df_cont$ratings, defaced =df_cont$defaced)
conTable <- table(df_cont_small)
df_cont_freq <- as.data.frame(conTable)
df_cont_freq
# Out:
#    rater   ratings    defaced  Freq
# 1  rater01 excluded   original 52
# 2  rater02 excluded   original 57
# 3  rater03 excluded   original 47
# 4  rater04 excluded   original 52
# 5  rater01 0.1        original 50
# 6  rater02 0.1        original 49
# 7  rater03 0.1        original 55
# 8  rater04 0.1        original 49
# 9  rater01 poor       original 62
# 10 rater02 poor       original 54
# 11 rater03 poor       original 48
# 12 rater04 poor       original 51
# 13 rater01 0.3        original 47
# 14 rater02 0.3        original 47
# 15 rater03 0.3        original 59
# 16 rater04 0.3        original 58
# 17 rater01 acceptable original 54
# 18 rater02 acceptable original 59
# 19 rater03 acceptable original 62
# 20 rater04 acceptable original 55
# 21 rater01 0.5        original 56
# 22 rater02 0.5        original 59
# 23 rater03 0.5        original 44
# 24 rater04 0.5        original 46
# 25 rater01 good       original 50
# 26 rater02 good       original 44
# 27 rater03 good       original 40
# 28 rater04 good       original 40
# 29 rater01 0.7        original 58
# 30 rater02 0.7        original 56
# ⋮  ⋮       ⋮          ⋮        ⋮
# 59 rater03 0.3        defaced   49
# 60 rater04 0.3        defaced   47
# 61 rater01 acceptable defaced   51
# 62 rater02 acceptable defaced   59
# 63 rater03 acceptable defaced   55
# 64 rater04 acceptable defaced   52
# 65 rater01 0.5        defaced   54
# 66 rater02 0.5        defaced   58
# 67 rater03 0.5        defaced   54
# 68 rater04 0.5        defaced   58
# 69 rater01 good       defaced   53
# 70 rater02 good       defaced   45
# 71 rater03 good       defaced   49
# 72 rater04 good       defaced   55
# 73 rater01 0.7        defaced   57
# 74 rater02 0.7        defaced   58
# 75 rater03 0.7        defaced   49
# 76 rater04 0.7        defaced   50
# 77 rater01 very good  defaced   53
# 78 rater02 very good  defaced   55
# 79 rater03 very good  defaced   53
# 80 rater04 very good  defaced   35
# 81 rater01 0.9        defaced   40
# 82 rater02 0.9        defaced   46
# 83 rater03 0.9        defaced   62
# 84 rater04 0.9        defaced   65
# 85 rater01 excellent  defaced   61
# 86 rater02 excellent  defaced   64
# 87 rater03 excellent  defaced  117
# 88 rater04 excellent  defaced  155

# %%
library(ggplot2)
## Bar plot
ggplot(df_cont_freq, aes(x = rater, y = Freq))+
  geom_bar(
    aes(fill = ratings), stat = "identity", color = "white",
    position = position_dodge(0.9) 
    )+
  facet_wrap(~defaced)+
  theme(text = element_text(size = 25))+
  theme(axis.text.x = element_text(size = 15))
# Out:
# plot without title

# %% [markdown]
# ## Other plots attempt

# %%
## Boxplot
#change size of displayed plot
library(repr)
options(repr.plot.width=20, repr.plot.height=10)

#create color vector
myColors <- ifelse(levels(df$defaced)=="defaced" , rgb(0.8,0.1,0.3,0.6) , 
              ifelse(levels(df$defaced)=="original", "grey90",
              "grey90" ) )

boxplot(ratings~defaced+rater, data=df, col=myColors)

#Add legend
legend(22,1.5, legend = c("Original","Defaced") , bg='lightblue',
    col = c('grey90', rgb(0.8,0.1,0.3,0.6)) , bty = "n", pch=20 , pt.cex = 3, 
    cex = 1, horiz = FALSE, inset = c(0.03, 0.1), box.lty=1)
# Out:
# plot without title

# %%
## Violinplot
library(ggplot2)
p <- ggplot(df, aes(x=rater, y=as.numeric(ratings), fill=defaced)) + geom_violin()
p
# Out:
# plot without title

# %%
## Balloon plot
library(ggplot2)
ggballoonplot(df_freq, x = "rater", y = "ratings", size = "Freq",
              fill = "Freq", facet.by = "defaced",
              ggtheme = theme_bw()) +
  scale_fill_viridis_c(option = "C")
# Out:
# Error in ggballoonplot(df_freq, x = "rater", y = "ratings", size = "Freq", : could not find function "ggballoonplot"
# Traceback:
