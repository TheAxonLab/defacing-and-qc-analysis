# %% [markdown]
# # Defacing pre-registration - Statistical analysis in R

# %% [markdown]
# In this notebook, we are varying all dataset parameters (i.e number of subjects, raters, ratings levels) in the quest of a model that does not converge to a singular solution.The model is based on the formula `defaced + (defaced|rater)`. We did not successfully found such a model.

# %% [markdown]
# ### Function to simulate data with missing values

# %%
source("simulate_data.R")

# %% [markdown]
# ## Starting model

# %% [markdown]
# We are automatically dropping ratings to test if missing values helps the model to converge to a non-singular value.
# We fixe the percentage of biased scans per rater to around 50%. This percentage has been informed by our preliminary study. For both raters, ~50% of the scans were rated differently between the defaced and non-defaced conditions.

# %%
n_sub <- 580 #nbr of subjects available in the dataset
n_drop <- 100
n_rater <- 4 #nbr of raters
#Define for each rater the percentage of biased ratings
perc_biased <- c(2,40,60,80)
ratings_range <- 1:4
labels <- c('excluded','poor','good','excellent')
bias <- 1

library(coefplot2)

for (j in seq(0, n_sub, by=n_drop)){
    print(sprintf("_______________%.02f missing values__________", j*100/n_sub))
    
    df <- simulate_data(n_sub-j, n_sub, n_rater, perc_biased, ratings_range=ratings_range, bias=bias)
    
    library(lme4)
    fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df, na.action=na.omit, REML = TRUE)
    
    print(summary(fm1)) 
    
}
# Out:
# Loading required package: coda
# [1] "_______________0.00 missing values__________"
# Loading required package: Matrix
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 14045.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7936 -0.7645  0.1469  1.0583  1.4661
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.01095  0.1047
#  Residual             1.20384  1.0972
# Number of obs: 4640, groups:  rater, 4
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.48966    0.05707   43.62
# defaceddefaced  0.34267    0.03221   10.64
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.282
# [1] "_______________17.24 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 11579.2
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -1.77721 -0.85740  0.05973  0.97686  1.53129
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.01841  0.1357
#  Residual             1.18889  1.0904
# Number of obs: 3840, groups:  rater, 4
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.50260    0.07226  34.631
# defaceddefaced  0.33125    0.03519   9.413
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.243
# [1] "_______________34.48 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 9138.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7902 -0.8068  0.1150  0.9753  1.5682
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.0183   0.1353
#  Residual             1.1767   1.0848
# Number of obs: 3040, groups:  rater, 4
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.48684    0.07313  34.005
# defaceddefaced  0.34474    0.03935   8.761
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.269
# [1] "_______________51.72 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 6718.4
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -1.79734 -0.84017  0.08509  0.99509  1.48298
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.01092  0.1045
#  Residual             1.16808  1.0808
# Number of obs: 2240, groups:  rater, 4
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.53929    0.06142  41.342
# defaceddefaced  0.33839    0.04567   7.409
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.372
# [1] "_______________68.97 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 4303.2
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -1.82734 -0.76048  0.06168  0.96846  1.57220
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.02423  0.1556
#  Residual             1.15141  1.0730
# Number of obs: 1440, groups:  rater, 4
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.51111    0.08750  28.699
# defaceddefaced  0.32639    0.05655   5.771
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.323
# [1] "_______________86.21 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 1854.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.9774 -0.7931  0.1855  0.9582  1.5814
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.02351  0.1533
#  Residual             1.04434  1.0219
# Number of obs: 640, groups:  rater, 4
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.53437    0.09561  26.508
# defaceddefaced  0.35313    0.08079   4.371
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.423

# %% [markdown]
# ## Modify nbr of raters

# %%
n_sub <- 580 #nbr of subjects available in the dataset
n_drop <- 100
n_rater <- 100 #nbr of raters
#Define for each rater the percentage of biased ratings
perc_biased <- rep(c(2,20,40,40,50,50,60,60,60,80), times = n_rater/10)
ratings_range <- 1:4
labels <- c('excluded','poor','good','excellent')
bias <- 1

library(coefplot2)

for (j in seq(0, n_sub, by=n_drop)){
    print(sprintf("_______________%.02f missing values__________", j*100/n_sub))
    
    df <- simulate_data(n_sub-j, n_sub, n_rater, perc_biased, ratings_range=ratings_range, bias=bias)
    
    library(lme4)
    fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df, na.action=na.omit, REML = TRUE)
    
    print(summary(fm1)) 
    
}
# Out:
# [1] "_______________0.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 349334.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8400 -0.7936  0.1220  1.0172  1.5529
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.006315 0.07947
#  Residual             1.187448 1.08970
# Number of obs: 116000, groups:  rater, 100
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.498897   0.009145  273.26
# defaceddefaced 0.346345   0.006399   54.12
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.350
# [1] "_______________17.24 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 289196.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8487 -0.7994  0.1180  1.0155  1.6006
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.008084 0.08991
#  Residual             1.188082 1.08999
# Number of obs: 96000, groups:  rater, 100
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.497625   0.010276   243.1
# defaceddefaced 0.346854   0.007036    49.3
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.342
# [1] "_______________34.48 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 228817.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8700 -0.7837  0.1306  1.0215  1.5727
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.008339 0.09132
#  Residual             1.185623 1.08886
# Number of obs: 76000, groups:  rater, 100
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.496579   0.010705   233.2
# defaceddefaced 0.345211   0.007899    43.7
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.369
# [1] "_______________51.72 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 168602
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8641 -0.7886  0.1328  1.0126  1.5948
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.009459 0.09726
#  Residual             1.184842 1.08850
# Number of obs: 56000, groups:  rater, 100
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)      2.5023     0.0117  213.86
# defaceddefaced   0.3462     0.0092   37.63
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.393
# [1] "_______________68.97 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 108380.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8520 -0.8007  0.1185  1.0074  1.6071
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.009349 0.09669
#  Residual             1.183647 1.08796
# Number of obs: 36000, groups:  rater, 100
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.50833    0.01262  198.77
# defaceddefaced  0.34417    0.01147   30.01
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.454
# [1] "_______________86.21 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 48216.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8276 -0.7673  0.1451  1.0393  1.5503
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.008228 0.09071
#  Residual             1.185643 1.08887
# Number of obs: 16000, groups:  rater, 100
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.48250    0.01518   163.5
# defaceddefaced  0.34600    0.01722    20.1
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.567

# %%
n_sub <- 580 #nbr of subjects available in the dataset
n_drop <- 100
n_rater <- 20 #nbr of raters
#Define for each rater the percentage of biased ratings
perc_biased <- rep(c(2,20,40,40,50,50,60,60,60,80), times = n_rater/10)
ratings_range <- 1:4
labels <- c('excluded','poor','good','excellent')
bias <- 1

library(coefplot2)

for (j in seq(0, n_sub, by=n_drop)){
    print(sprintf("_______________%.02f missing values__________", j*100/n_sub))
    
    df <- simulate_data(n_sub-j, n_sub, n_rater, perc_biased, ratings_range=ratings_range, bias=bias)
    
    library(lme4)
    fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df, na.action=na.omit, REML = TRUE)
    
    print(summary(fm1)) 
    
}
# Out:
# [1] "_______________0.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 69587.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8094 -0.7906  0.1237  1.0177  1.5692
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007452 0.08632
#  Residual             1.172669 1.08290
# Number of obs: 23200, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.48897    0.02176   114.4
# defaceddefaced  0.34974    0.01422    24.6
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.327
# [1] "_______________17.24 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 57776.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8252 -0.8043  0.1209  1.0189  1.5896
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.009511 0.09752
#  Residual             1.183567 1.08792
# Number of obs: 19200, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.49417    0.02447  101.92
# defaceddefaced  0.34802    0.01570   22.16
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.321
# [1] "_______________34.48 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 45708.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7938 -0.7803  0.1399  1.0289  1.5466
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.006335 0.07959
#  Residual             1.181072 1.08677
# Number of obs: 15200, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.47842    0.02173  114.06
# defaceddefaced  0.35026    0.01763   19.87
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.406
# [1] "_______________51.72 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 33672.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8278 -0.7973  0.1235  1.0290  1.5312
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007302 0.08545
#  Residual             1.179450 1.08602
# Number of obs: 11200, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.49661    0.02399  104.05
# defaceddefaced  0.35000    0.02052   17.05
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.428
# [1] "_______________68.97 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 21669.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8144 -0.8042  0.1296  1.0184  1.5847
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.01073  0.1036
#  Residual             1.18116  1.0868
# Number of obs: 7200, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.50611    0.02940   85.24
# defaceddefaced  0.34528    0.02562   13.48
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.436
# [1] "_______________86.21 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 9649.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7303 -0.7652  0.1650  1.0676  1.4282
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.002527 0.05027
#  Residual             1.188944 1.09039
# Number of obs: 3200, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.47562    0.02949  83.957
# defaceddefaced  0.34563    0.03855   8.965
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.654

# %% [markdown]
# ## Modify number of subjects

# %%
n_sub <- 3000 #nbr of subjects available in the dataset
n_drop <- 100
n_rater <- 20 #nbr of raters
#Define for each rater the percentage of biased ratings
perc_biased <- rep(c(2,20,40,40,50,50,60,60,60,80), times = n_rater/10)
ratings_range <- 1:4
labels <- c('excluded','poor','good','excellent')
bias <- 1

library(coefplot2)

for (j in seq(0, n_sub, by=n_drop)){
    print(sprintf("_______________%.02f missing values__________", j*100/n_sub))
    
    df <- simulate_data(n_sub-j, n_sub, n_rater, perc_biased, ratings_range=ratings_range, bias=bias)
    
    library(lme4)
    fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df, na.action=na.omit, REML = TRUE)
    
    print(summary(fm1)) 
    
}
# Out:
# [1] "_______________0.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 361374.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7971 -0.7960  0.1212  1.0224  1.5269
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.005698 0.07549
#  Residual             1.188752 1.09030
# Number of obs: 120000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.496800   0.017456  143.03
# defaceddefaced 0.346517   0.006295   55.05
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.180
# [1] "_______________3.33 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 349181.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7983 -0.7982  0.1178  1.0191  1.5436
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.006363 0.07977
#  Residual             1.187205 1.08959
# Number of obs: 116000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.496845   0.018402  135.68
# defaceddefaced 0.344621   0.006398   53.86
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.174
# [1] "_______________6.67 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 337578.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7901 -0.8018  0.1142  1.0034  1.5357
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.006821 0.08259
#  Residual             1.191819 1.09170
# Number of obs: 112000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.505589   0.019035  131.63
# defaceddefaced 0.343982   0.006524   52.72
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.171
# [1] "_______________10.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 325239.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8415 -0.7909  0.1263  1.0056  1.5516
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007925 0.08902
#  Residual             1.188647 1.09025
# Number of obs: 108000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.500630   0.020451  122.27
# defaceddefaced 0.345389   0.006635   52.05
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.162
# [1] "_______________13.33 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 312893.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8232 -0.7987  0.1189  1.0213  1.5522
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007184 0.08476
#  Residual             1.185218 1.08868
# Number of obs: 104000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.498904   0.019544  127.86
# defaceddefaced 0.344827   0.006752   51.07
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.173
# [1] "_______________16.67 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 301709.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8154 -0.7994  0.1234  1.0182  1.5472
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007379 0.0859
#  Residual             1.195306 1.0933
# Number of obs: 100000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.499560   0.019821   126.1
# defaceddefaced 0.344380   0.006915    49.8
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.174
# [1] "_______________20.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 288409.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8317 -0.8045  0.1160  1.0093  1.5544
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007135 0.08447
#  Residual             1.180044 1.08630
# Number of obs: 96000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.507729   0.019528  128.41
# defaceddefaced 0.345958   0.007012   49.34
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.180
# [1] "_______________23.33 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 276428.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8177 -0.7939  0.1185  1.0161  1.5601
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007612 0.08725
#  Residual             1.180460 1.08649
# Number of obs: 92000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.489696   0.020156   123.5
# defaceddefaced 0.348196   0.007164    48.6
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.178
# [1] "_______________26.67 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 265268.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7907 -0.7869  0.1290  1.0227  1.5264
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.006886 0.08298
#  Residual             1.192033 1.09180
# Number of obs: 88000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.496409   0.019271  129.54
# defaceddefaced 0.345886   0.007361   46.99
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.191
# [1] "_______________30.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 253193.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8493 -0.7922  0.1279  1.0044  1.5566
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.009106 0.09543
#  Residual             1.191675 1.09164
# Number of obs: 84000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.498881   0.021993  113.62
# defaceddefaced 0.343762   0.007533   45.63
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.171
# [1] "_______________33.33 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 241098.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7938 -0.8092  0.1070  1.0165  1.5153
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.005747 0.07581
#  Residual             1.191191 1.09142
# Number of obs: 80000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.496200   0.017808  140.18
# defaceddefaced 0.345625   0.007717   44.78
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.217
# [1] "_______________36.67 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 228986.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8025 -0.7841  0.1240  1.0221  1.5302
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.00719  0.08479
#  Residual             1.19019  1.09096
# Number of obs: 76000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.496711   0.019769  126.29
# defaceddefaced 0.344737   0.007915   43.56
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.200
# [1] "_______________40.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 216416.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8282 -0.7859  0.1340  1.0123  1.5713
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007781 0.08821
#  Residual             1.181584 1.08701
# Number of obs: 72000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.497722   0.020539   121.6
# defaceddefaced 0.345139   0.008102    42.6
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.197
# [1] "_______________43.33 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 204644.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8445 -0.7967  0.1216  1.0153  1.5224
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.006148 0.07841
#  Residual             1.185969 1.08902
# Number of obs: 68000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.505088   0.018501  135.40
# defaceddefaced 0.344382   0.008352   41.23
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.226
# [1] "_______________46.67 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 192917
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7974 -0.7927  0.1234  0.9992  1.5166
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.0063   0.07937
#  Residual             1.1917   1.09164
# Number of obs: 64000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.51087    0.01877  133.78
# defaceddefaced  0.34206    0.00863   39.64
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.230
# [1] "_______________50.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 180687.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8117 -0.7952  0.1231  1.0254  1.5608
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007195 0.08482
#  Residual             1.188156 1.09003
# Number of obs: 60000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.49923    0.01998  125.06
# defaceddefaced  0.34597    0.00890   38.87
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.223
# [1] "_______________53.33 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 168559.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8467 -0.7871  0.1311  0.9942  1.5392
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.009864 0.09932
#  Residual             1.186230 1.08914
# Number of obs: 56000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.501857   0.023143  108.11
# defaceddefaced 0.347357   0.009205   37.74
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.199
# [1] "_______________56.67 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 156747.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8318 -0.8004  0.1158  1.0097  1.5315
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007254 0.08517
#  Residual             1.191474 1.09155
# Number of obs: 52000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.492192   0.020211  123.31
# defaceddefaced 0.346346   0.009573   36.18
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.237
# [1] "_______________60.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 144698.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8227 -0.8047  0.1114  1.0124  1.5401
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.008861 0.09413
#  Residual             1.191511 1.09156
# Number of obs: 48000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    2.503000   0.022197  112.76
# defaceddefaced 0.343625   0.009965   34.48
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.224
# [1] "_______________63.33 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 132386.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7919 -0.7956  0.1019  1.0109  1.5442
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.006969 0.08348
#  Residual             1.184664 1.08842
# Number of obs: 44000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.49650    0.02006  124.47
# defaceddefaced  0.34791    0.01038   33.52
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.259
# [1] "_______________66.67 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 120137
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8066 -0.7765  0.1355  1.0260  1.5337
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.006141 0.07837
#  Residual             1.178268 1.08548
# Number of obs: 40000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.49320    0.01913  130.33
# defaceddefaced  0.34895    0.01085   32.15
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.284
# [1] "_______________70.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 108254.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8346 -0.7916  0.1281  1.0128  1.5294
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.008104 0.09002
#  Residual             1.182296 1.08733
# Number of obs: 36000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.50017    0.02170  115.22
# defaceddefaced  0.34789    0.01146   30.35
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.264
# [1] "_______________73.33 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 96165.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8169 -0.7981  0.1225  1.0202  1.5173
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.005461 0.0739
#  Residual             1.180117 1.0863
# Number of obs: 32000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.50294    0.01862  134.40
# defaceddefaced  0.35119    0.01215   28.91
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.326
# [1] "_______________76.67 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 84060.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8531 -0.8006  0.1214  1.0114  1.5243
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.006445 0.08028
#  Residual             1.176289 1.08457
# Number of obs: 28000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.50914    0.02016  124.48
# defaceddefaced  0.34579    0.01296   26.68
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.322
# [1] "_______________80.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 72167.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8191 -0.7843  0.1356  1.0323  1.5030
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.006121 0.07824
#  Residual             1.181749 1.08708
# Number of obs: 24000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.49492    0.02011     124
# defaceddefaced  0.35083    0.01403      25
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.349
# [1] "_______________83.33 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 60118.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8167 -0.8068  0.1186  0.9985  1.5109
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007637 0.08739
#  Residual             1.180009 1.08628
# Number of obs: 20000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.50940    0.02236  112.24
# defaceddefaced  0.34700    0.01536   22.59
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.344
# [1] "_______________86.67 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 48019.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8101 -0.7761  0.1468  1.0103  1.5417
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.007949 0.08916
#  Residual             1.173993 1.08351
# Number of obs: 16000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.48088    0.02333  106.34
# defaceddefaced  0.34675    0.01713   20.24
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.367
# [1] "_______________90.00 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 36070.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8052 -0.7964  0.1300  1.0141  1.4801
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.005213 0.0722
#  Residual             1.179394 1.0860
# Number of obs: 12000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.51000    0.02138  117.39
# defaceddefaced  0.35000    0.01983   17.65
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.464
# [1] "_______________93.33 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 24091.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8251 -0.7721  0.1451  1.0271  1.5078
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.006778 0.08233
#  Residual             1.184608 1.08840
# Number of obs: 8000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.49075    0.02520   98.84
# defaceddefaced  0.34750    0.02434   14.28
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.483
# [1] "_______________96.67 missing values__________"
# Linear mixed model fit by REML ['lmerMod']
# Formula: as.numeric(ratings) ~ defaced + (1 | rater)
#    Data: df
#
# REML criterion at convergence: 12017.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8094 -0.7992  0.1239  1.0036  1.4913
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  rater    (Intercept) 0.008408 0.09169
#  Residual             1.173401 1.08324
# Number of obs: 4000, groups:  rater, 20
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)     2.53000    0.03173   79.72
# defaceddefaced  0.33400    0.03425    9.75
#
# Correlation of Fixed Effects:
#             (Intr)
# defaceddfcd -0.540
# [1] "_______________100.00 missing values__________"
# Error in lme4::lFormula(formula = as.numeric(ratings) ~ defaced + (1 | : 0 (non-NA) cases
# Traceback:
#
# 1. lmer(as.numeric(ratings) ~ defaced + (1 | rater), data = df,
#  .     na.action = na.omit, REML = TRUE)
# 2. eval(mc, parent.frame(1L))
# 3. eval(mc, parent.frame(1L))
# 4. lme4::lFormula(formula = as.numeric(ratings) ~ defaced + (1 |
#  .     rater), data = df, REML = TRUE, na.action = na.omit, control = structure(list(
#  .     optimizer = "nloptwrap", restart_edge = TRUE, boundary.tol = 1e-05,
#  .     calc.derivs = TRUE, use.last.params = FALSE, checkControl = list(
#  .         check.nobs.vs.rankZ = "ignore", check.nobs.vs.nlev = "stop",
#  .         check.nlev.gtreq.5 = "ignore", check.nlev.gtr.1 = "stop",
#  .         check.nobs.vs.nRE = "stop", check.rankX = "message+drop.cols",
#  .         check.scaleX = "warning", check.formula.LHS = "stop"),
#  .     checkConv = list(check.conv.grad = list(action = "warning",
#  .         tol = 0.002, relTol = NULL), check.conv.singular = list(
#  .         action = "message", tol = 1e-04), check.conv.hess = list(
#  .         action = "warning", tol = 1e-06)), optCtrl = list()), class = c("lmerControl",
#  . "merControl")))
# 5. stop("0 (non-NA) cases")

# %%
n_sub <- 20 #nbr of subjects available in the dataset
n_drop <- 6
n_rater <- 20 #nbr of raters
#Define for each rater the percentage of biased ratings
perc_biased <- rep(c(2,20,40,40,50,50,60,60,60,80), times = n_rater/10)
ratings_range <- 1:4
labels <- c('excluded','poor','good','excellent')
bias <- 1

library(coefplot2)

for (j in seq(0, n_sub, by=n_drop)){
    print(sprintf("_______________%.02f missing values__________", j*100/n_sub))
    
    df <- simulate_data(n_sub-j, n_sub, n_rater, perc_biased, ratings_range=ratings_range, bias=bias)
    
    library(lme4)
    fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df, na.action=na.omit, REML = TRUE)
    
    print(summary(fm1)) 
    
}

# %% [markdown]
# ## Change ratings levels

# %% [markdown]
# ### Make ratings closer to continuous

# %%
n_sub <- 580 #nbr of subjects available in the dataset
n_drop <- 100
n_rater <- 20 #nbr of raters
#Define for each rater the percentage of biased ratings
perc_biased <- rep(c(2,20,40,40,50,50,60,60,60,80), times = n_rater/10)
ratings_range <- seq(0,1,length.out=11)
labels <- c('excluded','0.1','poor','0.3','acceptable','0.5','good','0.7','very good','0.9','excellent')
bias <- 0.1

library(coefplot2)

for (j in seq(0, n_sub, by=n_drop)){
    print(sprintf("_______________%.02f missing values__________", j*100/n_sub))
    
    df <- simulate_data(n_sub-j, n_sub, n_rater, perc_biased, ratings_range=ratings_range, bias=bias)
    
    library(lme4)
    fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df, na.action=na.omit, REML = TRUE)
    
    print(summary(fm1)) 
    
}

# %%
n_sub <- 580 #nbr of subjects available in the dataset
n_drop <- 100
n_rater <- 20 #nbr of raters
#Define for each rater the percentage of biased ratings
perc_biased <- rep(c(2,20,40,40,50,50,60,60,60,80), times = n_rater/10)
ratings_range <- seq(0,1,length.out=51)
bias <- 0.1

library(coefplot2)

for (j in seq(0, n_sub, by=n_drop)){
    print(sprintf("_______________%.02f missing values__________", j*100/n_sub))
    
    df <- simulate_data(n_sub-j, n_sub, n_rater, perc_biased, ratings_range=ratings_range, bias=bias)
    
    library(lme4)
    fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df, na.action=na.omit, REML = TRUE)
    
    print(summary(fm1)) 
    
}

# %% [markdown]
# ### Change the ratings' levels

# %%
n_sub <- 580 #nbr of subjects available in the dataset
n_drop <- 100
n_rater <- 20 #nbr of raters
#Define for each rater the percentage of biased ratings
perc_biased <- rep(c(2,20,40,40,50,50,60,60,60,80), times = n_rater/10)
ratings_range <- seq(0,10,length.out=11)
bias <- 1

library(coefplot2)

for (j in seq(0, n_sub, by=n_drop)){
    print(sprintf("_______________%.02f missing values__________", j*100/n_sub))
    
    df <- simulate_data(n_sub-j, n_sub, n_rater, perc_biased, ratings_range=ratings_range, bias=bias)
    
    library(lme4)
    fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df, na.action=na.omit, REML = TRUE)
    
    print(summary(fm1)) 
    
}

# %%
n_sub <- 580 #nbr of subjects available in the dataset
n_drop <- 100
n_rater <- 20 #nbr of raters
#Define for each rater the percentage of biased ratings
perc_biased <- rep(c(2,20,40,40,50,50,60,60,60,80), times = n_rater/10)
ratings_range <- seq(0,1000,length.out=11)
bias <- 100

library(coefplot2)

for (j in seq(0, n_sub, by=n_drop)){
    print(sprintf("_______________%.02f missing values__________", j*100/n_sub))
    
    df <- simulate_data(n_sub-j, n_sub, n_rater, perc_biased, ratings_range=ratings_range, bias=bias)
    
    library(lme4)
    fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced| rater), data=df, na.action=na.omit, REML = TRUE)
    
    print(summary(fm1)) 
    
}

# %% [markdown]
# ## All raters rate same subset of data

# %%
## Load data
n_rated <- 130
n_sub <- 130 #nbr of subjects available in the dataset
n_rater <- 20 #nbr of raters
#perc_biased <- c(2,40,60,90) #4 raters + bias
perc_biased <- rep(c(2,20,40,40,40,40,60,60,60,80), times = n_rater/10)

df_4 <- simulate_data(n_rated, n_sub, n_rater, perc_biased)

## Fit model
library(lme4)
fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df_4)
summary(fm1)
ranef(fm1)

# %%
## Load data
n_rated <- 50
n_sub <- 50 #nbr of subjects available in the dataset
n_rater <- 20 #nbr of raters
#perc_biased <- c(2,40,60,90) #4 raters + bias
perc_biased <- rep(c(2,20,40,40,40,40,60,60,60,80), times = n_rater/10)

df_4 <- simulate_data(n_rated, n_sub, n_rater, perc_biased)

## Fit model
library(lme4)
fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df_4)
summary(fm1)
ranef(fm1)

# %%
## Load data
n_rated <- 1000
n_sub <- 1000 #nbr of subjects available in the dataset
n_rater <- 20 #nbr of raters
#perc_biased <- c(2,40,60,90) #4 raters + bias
perc_biased <- rep(c(2,20,40,40,40,40,60,60,60,80), times = n_rater/10)

df_4 <- simulate_data(n_rated, n_sub, n_rater, perc_biased)

## Fit model
library(lme4)
fm1 <- lmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df_4)
summary(fm1)
ranef(fm1)

# %% [markdown]
# ## Use partial bayesian method

# %% [markdown]
# The help for ?isSingular suggests trying the blme package. "Use a partially Bayesian method that produces maximum a posteriori (MAP) estimates using regularizing priors to force the estimated random-effects variance-covariance matrices away from singularity"

# %%
library(blme)
n_rated <- 130
n_sub <- 580 #nbr of subjects available in the dataset
n_rater <- 20 #nbr of raters
#perc_biased <- c(2,40,60,80) #4 raters + bias
perc_biased <- rep(c(2,20,40,40,40,40,60,60,60,80), times = n_rater/10)
ratings_range <- seq(0,1,length.out=11)
labels <- c('excluded','0.1','poor','0.3','acceptable','0.5','good','0.7','very good','0.9','excellent')
bias <- 0.1

df_bay <- simulate_data(n_rated, n_sub, n_rater, perc_biased, ratings_range=ratings_range, bias=bias)

fm1_bay <- blmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df_bay)
summary(fm1_bay)

# %%
library(blme)
n_rated <- 580
n_sub <- 580 #nbr of subjects available in the dataset
n_rater <- 4 #nbr of raters
perc_biased <- c(2,40,60,80) #4 raters + bias
ratings_range <- seq(0,1,length.out=11)
labels <- c('excluded','0.1','poor','0.3','acceptable','0.5','good','0.7','very good','0.9','excellent')
bias <- 0.1

df_bay <- simulate_data(n_rated, n_sub, n_rater, perc_biased, ratings_range=ratings_range, bias=bias)

fm1_bay <- blmer(as.numeric(ratings) ~ defaced + (defaced | rater), data=df_bay)
summary(fm1_bay)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The model always converge to a singular answer no matter which dataset parameters I changed. The bayesian extension of the model does not converge as well.

# %% [markdown]
# A last lead to explore is to use full bayesian model. However it takes a long time to run and the framework is completely different.

# %%
library(brms)

n_rated <- 20
n_sub <- 20 #nbr of subjects available in the dataset
n_rater <- 6 #nbr of raters
perc_biased <- c(2,40,50,50,60,90) #4 raters + bias

df_bay <- simulate_data(n_rated, n_sub, n_rater, perc_biased)

fm1_bay <- brm(as.numeric(ratings) ~ defaced + (defaced | rater), data=df_bay, family=cratio("logit"))
summary(fm1_bay)
plot(fm1_bay)
